# %%
import numpy as np 
import pandas as pd
from math import isnan

from unicodedata import normalize
from collections import Counter

import plotly.plotly as py 
import plotly.tools as tls 
import plotly.graph_objs as go

tls.set_credentials_file(username="danybr92", api_key = 'hfUIzJvZlRRk1PKFLkRP')

# %%
tweets = pd.read_csv("./data/train_lan_ca.txt",sep = ";")
tweets.head()
# Out:
#           username                 date  retweets  favorites  \
# 0  TERRATAlexandre  2017-08-18 21:30:01         0          0
# 1        davi85zgz  2017-08-18 14:22:45         1          2
# 2    Cuadrofactory  2017-08-18 14:10:01         0          0
# 3   soyluisgabriel  2017-08-18 11:20:00         1          1
# 4  elperriodiquero  2017-08-18 10:41:43         0          0
#
#                                                 text emoticon  \
# 0  #Barcelona #Catalunya #Espagne #Spain #Barcelo...       []
# 1  Me cago en la puta!!! #VIVA #ESPAÑA #EspanaUni...       []
# 2  #Barcelona #Cambrils #EspanaUnida pic.twitter....       []
# 3  #Cambrils #Barcelona #EspanaUnida pic.twitter....       []
# 4  #Cambrils #EspanaUnida #PrayforBarcelona #Fuer...       []
#
#                 location                                  mentions  \
# 0                    NaN  @IREMAM7310 @FranceauQatar @guardiacivil
# 1  Zaragoza,Spain,Aragón                                       NaN
# 2                    NaN                                       NaN
# 3                    NaN                                       NaN
# 4                    NaN                                       NaN
#
#                                              hashtag                  id  \
# 0  #Barcelona #Catalunya #Espagne #Spain #Barcelo...  898658267391545345
# 1                         #VIVA #ESPAÑA #EspanaUnida  898550740267958272
# 2                  #Barcelona #Cambrils #EspanaUnida  898547537589784579
# 3                  #Cambrils #Barcelona #EspanaUnida  898504751846797312
# 4  #Cambrils #EspanaUnida #PrayforBarcelona #Fuer...  898495114775056384
#
#                                            permalink language  \
# 0  https://twitter.com/TERRATAlexandre/status/898...       ca
# 1  https://twitter.com/davi85zgz/status/898550740...       ca
# 2  https://twitter.com/Cuadrofactory/status/89854...       ca
# 3  https://twitter.com/soyluisgabriel/status/8985...       ca
# 4  https://twitter.com/elperriodiquero/status/898...       ca
#
#              coordinates sentiment
# 0                    NaN  negative
# 1  41.6488226,-0.8890853  negative
# 2                    NaN  negative
# 3                    NaN  negative
# 4                    NaN  negative

# %%
tweets2 = tweets['coordinates'].str.split(",",expand = True)
tweets2.columns = ['lat','lon']
tweets['displayText'] = 'Retweets ' + tweets['retweets'].astype(str) + '<br>' + \
'State ' + tweets['language'].astype(str)

# %%
freqs = Counter(tweets['coordinates'])
#print(str(freqs))
coordinatesDict = {}
for k,v in freqs.items():
    coordinatesDict[k] = [0,0] #first inizialization, [0] is #positive, [1] is #negative

for coordinate,sentiment in zip(tweets['coordinates'],tweets['sentiment']):
    if coordinate != "":
        if sentiment == "positive":
            coordinatesDict[coordinate][0] += 1
        elif sentiment == "negative":
            coordinatesDict[coordinate][1] += 1
#print("----")
#print(str(coordinatesDict))
clean_dict = filter(lambda k: not isnan(k), coordinatesDict)
print(str(coordinatesDict))
# Out:
3744315,1.16159': [4, 0], '42.18220780000001,2.4880242': [14, 0], '40.775858,0.4313729': [1, 0], '41.924627,2.3210736': [5, 0], '41.3848607,1.9317305': [1, 0], '42.3243687,0.9365927000000001': [7, 0], '41.3971819,1.1029318': [9, 0], '41.7225184,2.9302653': [3, 0], '41.940098,2.3162571': [8, 0], '42.1779464,2.7950993': [4, 0], '41.8271079,1.8922257': [27, 0], '41.2491051,1.2969289': [1, 0], '42.0281086,1.8855057': [3, 0], '41.5911589,1.5208624': [18, 0], '41.9939512,1.5160212': [3, 0], '42.4103118,1.1287747': [3, 0], '41.8297094,3.0476046': [3, 0], '41.6172338,2.0873256': [4, 0], '41.2093608,1.1977158': [2, 0], '41.6933493,2.2778128': [12, 0], '41.5450948,2.2089109': [7, 1], '41.0666754,1.0603606': [13, 0], '42.2002357,2.6953375': [3, 0], '41.89138519999999,3.1528692': [1, 0], '41.9938401,1.0197244': [2, 0], '41.5309648,1.685923': [1, 0], '41.9535354,3.2025863': [1, 0], '41.4803984,1.9148091': [5, 0], '41.4964205,2.3218228': [7, 0], '41.7902198,2.7776036': [5, 0], '41.611353,1.8464648': [1, 0], '42.1758038,2.9906822': [2, 0], '41.5096571,2.2335066': [1, 0], '41.1266553,0.8026232999999999': [1, 0], '41.6528561,2.7630471': [4, 0], '41.3772561,2.0910377': [13, 0], '40.8839435,0.7996491': [5, 0], '41.4946642,2.3591531': [11, 0], '42.2528434,2.9425698': [3, 0], '41.6838422,1.2794744': [8, 0], '41.5849177,1.612949': [14, 0], '41.4336754,2.1857902': [2, 0], '41.623783 ...

# %%
## Sentiment trading in the time
##

temp = tweets['date'].tolist()
dates = []
for date in temp:
    dates.append(date.split(" ")[0]) #working
print(str(dates))
freqs = Counter(dates)
freqs = sorted(freqs.items())
print("Freqs are:\n")
print(str(freqs))


dateDict = {}
for k,v in freqs:
    dateDict[k] = [0,0] #first inizialization, [0] is #positive, [1] is #negative

for date,sentiment in zip(dates,tweets['sentiment']):
    if date != "":
        if sentiment == "positive":
            dateDict[date][0] += 1
        elif sentiment == "negative":
            dateDict[date][1] += 1
            
print("Dictionary is:\n")
print(str(dateDict))
datesList = []
positiveList = []
negativeList = []
for date,sentiment in dateDict.items():
    #print("Date is: %s and sentiments are %s" % (date,sentiment))
    datesList.append(date)
    positiveList.append(sentiment[0])
    negativeList.append(sentiment[1])
# Out:
# ['2017-08-18', '2017-08-18', '2017-08-18', '2017-08-18', '2017-08-18', '2017-09-21', '2017-09-21', '2017-09-21', '2017-08-18', '2017-08-18', '2017-08-18', '2017-09-23', '2017-09-23', '2017-09-23', '2017-09-23', '2017-09-23', '2017-09-22', '2017-09-22', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-09-03', '2017-06-09', '2017-06-09', '2017-06-09', '2017-06-09', '2017-06
[471, 30], '2017-09-08': [479, 24], '2017-09-09': [884, 8], '2017-09-10': [533, 1], '2017-09-11': [2345, 5], '2017-09-12': [559, 7], '2017-09-13': [1036, 5], '2017-09-14': [1029, 8], '2017-09-15': [1138, 12], '2017-09-16': [2360, 16], '2017-09-17': [1306, 7], '2017-09-18': [788, 5], '2017-09-19': [1191, 7], '2017-09-20': [8159, 22], '2017-09-21': [4574, 25], '2017-09-22': [3066, 20], '2017-09-23': [2831, 29]}

# %%
trace_high = go.Scatter(
                x=datesList,
                y=positiveList,
                name = "Positive Sentiment",
                line = dict(color = 'E60014'),
                opacity = 0.8)

trace_low = go.Scatter(
                x=datesList,
                y=negativeList,
                name = "Negative Sentiment",
                line = dict(color = '#17BECF'),
                opacity = 0.8)

data = [trace_high,trace_low]

layout = dict(
    title = "Sentiment trading"
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Sentiment trading")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~danybr92/10.embed" height="525px" width="100%"></iframe>

# %%
## Sentiment trading with hashtags
##

temp = tweets['hashtag'].tolist()
hashtagsList = []
for line in temp:
    hashtags = line.split(" ")
    for hashtag in hashtags:
        hashtagsList.append(hashtag.lower()) #working
#print(str(hashtags))
freqs = Counter(hashtagsList)
#print("Freqs are:\n")
#print(str(freqs))

hashtagsList = []
counterList = []
for k,v in freqs.most_common(20):
    #print("hashtag is: %s with occurrence: %s" % (k,v))
    hashtagsList.insert(0,k)
    counterList.insert(0,v)
    
dist = [
    go.Bar(
        x=counterList,
        y=hashtagsList,
        orientation="h"
)]

#plotly.offline.iplot
py.iplot({"data":dist, "layout":go.Layout(title="Most common hashtags used")})
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~danybr92/47.embed" height="525px" width="100%"></iframe>

# %%
## Sentiment trading on a map
##

locationsUnique = tweets['location']
locationsUnique.fillna('', inplace = True)
#locationsUnique = pd.unique(tweets[['location'].values.ravel('K'))  #location at this point is 
locationsUnique = pd.unique(tweets[['location']].values.ravel('K'))           #already in the format city, state, region

cordinates = tweets['coordinates'].tolist()

print("LocationUnique length is:" + str(len(locationsUnique)))
#print(str(locationsUnique))

locationDict = {}
latDict = {}
lonDict = {}
for k in locationsUnique:
    if k != "":
        locationDict[k] = [0,0,0] #first inizialization, [0] is #positive, [1] is #negative
    
grouped = tweets.groupby(["location", "sentiment"]).size().reset_index(name="Time")
grouped.head(200)

for (idx, row) in grouped.iterrows():
    if row.location != "":
        #print("location is %s and sentiment is %s and coordinate is %s and time is %s" % (row.location, row.sentiment, row.coordinates, row.Time))%%!
        if row.sentiment == "positive":
            locationDict[row.location][0] = row.Time
        elif row.sentiment == "negative":
            locationDict[row.location][1] = row.Time
        elif row.sentiment == "neutral":
            locationDict[row.location][2] = row.Time
        #latLon = row.coordinates.split(",")
        #latDict[row.location] = latLon[0] 
        #lonDict[row.location] = latLon[1]

print("locationDict is:\n")
print(str(locationDict))
# Out:
# LocationUnique length is:459
# locationDict is:
#
# {'Zaragoza,Spain,Aragón': [0, 1, 0], 'Tarbes,France,Occitanie': [0, 1, 0], 'Òdena,Spain,CT': [3, 0, 0], 'Terrassa,Spain,CT': [95, 0, 0], 'Genève,Switzerland,GE': [5, 0, 0], 'Viladecans,Spain,CT': [20, 0, 0], 'Vallfogona de Riucorb,Spain,CT': [1, 0, 0], 'Barcelona,Spain,CT': [1317, 0, 3], 'Sabadell,Spain,CT': [60, 0, 0], 'Calella,Spain,CT': [9, 0, 0], 'Reus,Spain,CT': [54, 2, 0], 'Mataró,Spain,CT': [21, 0, 0], 'Ciudad de México,Mexico,CDMX': [4, 0, 0], 'Parets del Vallès,Spain,CT': [11, 0, 0], 'Santa Margarida de Montbui,Spain,CT': [2, 0, 0], 'Sant Climent de Llobregat,Spain,CT': [5, 0, 0], 'Prévessin-Moëns,France,Auvergne-Rhône-Alpes': [1, 0, 0], 'Granollers,Spain,CT': [25, 0, 0], 'Berga,Spain,CT': [9, 1, 0], 'Madrid,Spain,Comunidad de Madrid': [46, 1, 0], 'Guils de Cerdanya,Spain,CT': [1, 0, 0], 'Sant Pere de Ribes,Spain,CT': [2, 0, 1], 'Castelldefels,Spain,CT': [10, 0, 0], 'Girona,Spain,CT': [123, 0, 2], 'Manlleu,Spain,CT': [5, 0, 0], 'Palma,Spain,PM': [2, 0, 0], 'Pont de Molins,Spain,CT': [1, 0, 0], 'Sant Feliu de Guíxols,Spain,CT': [23, 0, 0], 'Balaguer,Spain,CT': [5, 0, 0], 'Vilafranca del Penedès,Spain,CT': [38, 0, 0], 'Lleida,Spain,CT': [42, 0, 3], 'Kallithea,Greece,None': [2, 0, 0], "L'Hospitalet de Llobregat,Spain,CT": [54, 0, 0], 'Oristà,Spain,CT': [1, 0, 0], 'Badalona,Spain,CT': [33, 0, 1], 'Sant Quirze de Besora,Spain,CT': [1, 0, 0], 'Vic,Spain,CT': [61, 3, 1], "Móra d'Ebre,Spain,CT": [1, 0, 0], 'Tordera,Spain,CT': [4, 0, 0], 'Palafrugell,Spain,CT': [9, 0, 0], 'Montcada i Reixac,Spain,CT': [6, 0, 0], 'Neda,Spain,GA': [1, 0, 0], "Castelló d'Empúries,Spain,CT": [1, 0, 0], 'Palamós,Spain,CT': [21, 0, 0], 'Sitges,Spain,CT': [3, 0, 0], 'Corbera de Llobregat,Spain,CT': [7, 0, 0], 'El Port de la Selva,Spain,CT': [1, 0, 0], 'Torredembarra,Spain,CT': [16, 0, 0], 'Sant Pere Pescador,Spain,CT': [8, 0, 0], 'Salt,Spain,CT': [15, 0, 0], 'Brive-la-Gaillarde,France,Nouvelle-Aquitaine': [1, 0, 0], 'Riudoms,Spain,CT': [3, 0, 0], 'Muntanyola,Spain,CT': [15, 0, 0], 'Sant Cugat del Vallès,Spain,CT': [42, 0, 0], 'Sant Adrià de Besòs,Spain,CT': [2, 0, 0], 'El Prat de Llobregat,Spain,CT': [8, 0, 0], "La Seu d'Urgell,Spain,CT": [10, 0, 0], 'Llançà,Spain,CT': [5, 0, 0], 'Pamplona,Spain,Navarra': [1, 1, 0], 'Premià de Dalt,Spain,CT': [1, 0, 0], 'Sant Boi de Llobregat,Spain,CT': [9, 0, 0], 'Tarragona,Spain,CT': [79, 0, 1], 'Banyoles,Spain,CT': [13, 0, 0], 'Blanes,Spain,CT': [5, 0, 0], 'Sant Esteve de Palautordera,Spain,CT': [1, 0, 0], 'Sant Antoni de Vilamajor,Spain,CT': [20, 0, 0], 'Amposta,Spain,CT': [9, 0, 0], 'Santa Maria de Palautordera,Spain,CT': [2, 0, 0], 'Manresa,Spain,CT': [36, 0, 0], 'Sant Fruitós de Bages,Spain,CT': [2, 0, 0], 'Firenze,Italy,Toscana': [3, 0, 0], 'El Papiol,Spain,CT': [1, 0, 0], 'Tipton,United States,IN': [1, 0, 0], "L'Aleixar,Spain,CT": [3, 0, 0], 'Montblanc,Spain,CT': [4, 0, 0], 'Olot,Spain,CT': [14, 0, 0], 'Roquetes,Spain,CT': [1, 0, 0], 'Sant Julià de Vilatorta,Spain,CT': [5, 0, 0], 'Vallirana,Spain,CT': [1, 0, 0], 'Senterada,Spain,CT': [7, 0, 0], "L'Espluga de Francolí,Spain,CT": [9, 0, 0], 'Tossa de Mar,Spain,CT': [3, 0, 0], 'Folgueroles,Spain,CT': [8, 0, 0], 'Esponellà,Spain,CT': [4, 0, 0], 'Sallent,Spain,CT': [27, 0, 0], 'Nulles,Spain,CT': [1, 0, 0], 'None,Spain,CT': [30, 0, 1], 'Jorba,Spain,CT': [18, 0, 0], 'Solsona,Spain,CT': [3, 0, 0], 'Sort,Spain,CT': [3, 0, 0], "Castell-Platja d'Aro,Spain,CT": [3, 0, 0], 'Castellar del Vallès,Spain,CT': [4, 0, 0], 'Vilallonga del Camp,Spain,CT': [2, 0, 0], 'La Garriga,Spain,CT': [12, 0, 0], 'Mollet del Vallès,Spain,CT': [7, 1, 0], 'Cambrils,Spain,CT': [13, 0, 0], 'Besalú,Spain,CT': [3, 0, 0], 'Mont-ras,Spain,CT': [1, 0, 0], 'Vilanova de Meià,Spain,CT': [2, 0, 0], 'Capellades,Spain,CT': [1, 0, 0], 'Begur,Spain,CT': [1, 0, 0], 'Martorell,Spain,CT': [5, 0, 0], 'Teià,Spain,CT': [7, 0, 0], 'Vidreres,Spain,CT': [5, 0, 0], 'Monistrol de Montserrat,Spain,CT': [1, 0, 0], 'Sant Miquel de Fluvià,Spain,CT': [2, 0, 0], 'Sant Fost de Campsentelles,Spain,CT': [1, 0, 0], 'Marçà,Spain, ...

# %%
grouped = grouped.drop(grouped.index[[0,1,2]])
grouped.head(10)
# Out:
#                                      location sentiment  Time
# 3    Abu Dhabi,United Arab Emirates,Abu Dhabi  positive     1
# 4                           Agramunt,Spain,CT  positive     1
# 5          Aguilares,El Salvador,San Salvador  positive     1
# 6          Alacant,Spain,Comunidad Valenciana  positive     1
# 7                             Alaior,Spain,PM   neutral     1
# 8   Alajuela,Costa Rica,Provincia de Alajuela  positive     1
# 9                            Albanyà,Spain,CT  positive     1
# 10                        Albatàrrec,Spain,CT  positive     6
# 11                            Albesa,Spain,CT  positive     1
# 12                            Albons,Spain,CT  positive     2

# %%
#grouped[grouped['location'] =="Badalona,Spain,CT"]
temp = tweets[['location','coordinates']]
temp = temp.drop_duplicates(subset = 'location')
#grouped.head(100)
new = pd.merge(grouped, temp, how='left', on = ['location'], copy=False)
#grouped.merge(temp,on = 'location', how='left', copy=False)
new.head(100)
# Out:
#                          location sentiment  Time  \
# 0              Aiguaviva,Spain,CT  positive     3
# 1                 Aitona,Spain,CT  positive     1
# 2                Albanyà,Spain,CT  positive     1
# 3             Albatàrrec,Spain,CT  positive     9
# 4                 Albesa,Spain,CT  positive     4
# 5                 Albons,Spain,CT  positive     3
# 6                Alcanar,Spain,CT  positive     6
# 7               Alcarràs,Spain,CT  negative     1
# 8               Alcarràs,Spain,CT  positive    10
# 9              Alcoletge,Spain,CT  positive     2
# 10               Alcover,Spain,CT  positive     4
# 11                Alella,Spain,CT  negative     1
# 12                Alella,Spain,CT  positive     3
# 13                 Alins,Spain,CT  positive     1
# 14                  Alió,Spain,CT  positive     6
# 15              Almoster,Spain,CT  positive     3
# 16                   Alp,Spain,CT  positive     1
# 17             Altafulla,Spain,CT  positive     2
# 18                  Amer,Spain,CT  positive     2
# 19               Amposta,Spain,CT  positive    19
# 20             Anglesola,Spain,CT  positive     1
# 21                Arbolí,Spain,CT  positive     1
# 22              Arbúcies,Spain,CT  positive     5
# 23         Arenys de Mar,Spain,CT  positive     6
# 24        Arenys de Munt,Spain,CT  negative     1
# 25        Arenys de Munt,Spain,CT  positive     7
# 26            Argelaguer,Spain,CT  negative     1
# 27            Argelaguer,Spain,CT  positive     2
# 28             Argentona,Spain,CT  positive    17
# 29       Artesa de Segre,Spain,CT  positive     1
# ..                            ...       ...   ...
# 70       Caldes d'Estrac,Spain,CT  positive     4
# 71   Caldes de Malavella,Spain,CT  negative     1
# 72   Caldes de Malavella,Spain,CT  positive     9
# 73               Calella,Spain,CT  positive    30
# 74           Calldetenes,Spain,CT  positive     2
# 75                Callús,Spain,CT  positive     2
# 76               Calonge,Spain,CT  positive    11
# 77              Camarles,Spain,CT  positive     2
# 78              Cambrils,Spain,CT  negative     1
# 79              Cambrils,Spain,CT  positive    25
# 80             Camprodon,Spain,CT  positive     2
# 81          Canet de Mar,Spain,CT  negative     1
# 82          Canet de Mar,Spain,CT  positive     9
# 83            Canovelles,Spain,CT  positive     5
# 84            Capellades,Spain,CT  positive     6
# 85              Capçanes,Spain,CT  positive     1
# 86              Cardedeu,Spain,CT  negative     3
# 87              Cardedeu,Spain,CT  positive    24
# 88               Cardona,Spain,CT  positive     1
# 89     Cassà de la Selva,Spain,CT  positive    22
# 90  Castell-Platja d'Aro,Spain,CT  negative     4
# 91  Castell-Platja d'Aro,Spain,CT  positive     9
# 92  Castellar del Vallès,Spain,CT  positive     8
# 93         Castellbisbal,Spain,CT  positive     7
# 94         Castelldefels,Spain,CT  negative     1
# 95         Castelldefels,Spain,CT  positive    32
# 96           Castellgalí,Spain,CT  positive     3
# 97            Castellolí,Spain,CT  positive     2
# 98           Castellserà,Spain,CT  positive     1
# 99         Castellterçol,Spain,CT  positive     2
#
#                       coordinates
# 0            41.9309069,2.7730027
# 1   41.4934916,0.4590822999999999
# 2            42.3047854,2.7204483
# 3             41.5733763,0.607391
# 4             41.752541,0.6595184
# 5              42.1048463,3.08392
# 6            40.5430578,0.4767476
# 7            41.5632511,0.5244194
# 8            41.5632511,0.5244194
# 9              41.647636,0.694722
# 10           41.2649546,1.1640968
# 11           41.4919653,2.2940817
# 12           41.4919653,2.2940817
# 13           42.5486199,1.3177031
# 14           41.2941858,1.3053578
# 15           41.1970367,1.1107223
# 16            42.3728449,1.886116
# 17           41.1469855,1.3806902
# 18           42.0104174,2.6028036
# 19           40.7067997,0.5801695
# 20    41.65719139999999,1.0837613
# 21           41.2426006,0.9487716
# 22            41.8165773,2.511129
# 23           41.5797073,2.5508683
# 24           41.6093683,2.5408414
# 25           41.6093683,2.5408414
# 26           42.2110383,2.6338156
# 27           42.2110383,2.6338156
# 28           41.5531639,2.4008466
# 29           41.8956604,1.0472421
# ..                            ...
# 70           41.5716858,2.5236717
# 71            41.8358025,2.807864
# 72            41.8358025,2.807864
# 73           41.6134346,2.6535552
# 74           41.9250982,2.2840953
# 75           41.7822924,1.7837062
# 76           41.8637896,3.0726468
# 77  40.7709311,0.6690033999999999
# 78           41.0666754,1.0603606
# 79           41.0666754,1.0603606
# 80    42.31366939999999,2.3651425
# 81           41.5998437,2.5767694
# 82           41.5998437,2.5767694
# 83    41.62378349999999,2.2679632
# 84            41.5309648,1.685923
# 85           41.1006811,0.7821062
# 86           41.6394024,2.3591531
# 87           41.6394024,2.3591531
# 88            41.913607,1.6797134
# 89           41.8862532,2.8751691
# 90           41.8297094,3.0476046
# 91           41.8297094,3.0476046
# 92           41.6172338,2.0873256
# 93            41.482929,1.9869293
# 94           41.2800161,1.9766294
# 95           41.2800161,1.9766294
# 96           41.6747239,1.8435319
# 97            41.598561,1.7052325
# 98  41.7458448,0.9874442999999999
# 99              41.7503185,2.1199
#
# [100 rows x 4 columns]

# %%
for (idx, row) in new.iterrows():
    if row.location != "":
        #print("location is %s and sentiment is %s and coordinate is %s and time is %s" % (row.location, row.sentiment, row.coordinates, row.Time))
        if row.sentiment == "positive":
            locationDict[row.location][0] = row.Time
        elif row.sentiment == "negative":
            locationDict[row.location][1] = row.Time
        elif row.sentiment == "neutral":
            locationDict[row.location][2] = row.Time
        latLon = row.coordinates.split(",")
        latDict[row.location] = latLon[0] 
        lonDict[row.location] = latLon[1]

#print("locationDict is:\n")
#print(str(locationDict))
# After that, what we have is:
#
# locationDict[location] = [#positive, #negative]
# latDict[location] = latitude
# lonDict[location] = longitute

latList = []
lonList = []
locationList = []
sentimentSize  = []
occurrencesSent = []
for loc,sentArray in locationDict.items():
    
    sentValue = sentArray[0]/(sentArray[0] + sentArray[1] + sentArray[2]) # to modify the weight
    occurrencesSent.append(str(sentArray[0] + sentArray[1] + sentArray[2]))
    #print("SentimentSize for %s is %s" % (loc,sentValue))
    sentimentSize.append(sentValue)
    latList.append(latDict[loc])
    lonList.append(lonDict[loc])
    locationList.append(loc)
    
new['SentimentSize'] = pd.DataFrame(data=sentimentSize)
new['occurrencesSent'] = pd.DataFrame(data=occurrencesSent)
tweets['displayText'] = 'SentimentSize ' + new['SentimentSize'].astype(str) + '<br>' + \
'Occorrence ' + new['occurrencesSent'] + '<br>' + \
'Location ' + new['location'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-623b4be567e6> in <module>()
#      31     #print("SentimentSize for %s is %s" % (loc,sentValue))
#      32     sentimentSize.append(sentValue)
# ---> 33     latList.append(latDict[loc])
#      34     lonList.append(lonDict[loc])
#      35     locationList.append(loc)
#
# KeyError: 'Agramunt,Spain,CT'

# %%
#new[['location','coordinates','SentimentSize']]

# %%
#for lat,lon,location in zip(latList,lonList,locationList):
#    print("%s..%s..%s" % (lat,lon,location))

# %%
data = [dict(type = 'scattergeo', locationmode = 'spain', lat = latList,lon = lonList, text = tweets['displayText'],
            marker = dict(size = 5, autocolorscale = False, colorscale = 'custom-colorscale', color = sentimentSize,
            colorbar = dict(title = 'Sentiment')))]

#marker = dict(size = 12, autocolorscale = False, colorscale = 'custom-colorscale', color = tweets['sentiment'],
            
layout = dict(title = "Tweets in Spain", colorbar = True, geo = dict(scope='world',projection = dict(type ='albers es'),
            showland = True, landcolor = "rgb(240,240,240)", subunitcolor = "rgb(217,217,217)", countrycolor = "rgb(217,217,217)", countrywidth = 0.5, subunitwidth = 0.5),)

fig = dict(data = data, layout = layout)

py.iplot(fig, validate = False, filename = 'd3-eval')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      21     try:
# ---> 22         parsed_content = response.json()
#      23     except ValueError:
#
# /anaconda3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#
# /anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#
# /anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#
# /anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)
#
# During handling of the above exception, another exception occurred:
#
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-56-89471578a3bb> in <module>()
#      10 fig = dict(data = data, layout = layout)
#      11
# ---> 12 py.iplot(fig, validate = False, filename = 'd3-eval')
#
# /anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     138     if 'auto_open' not in plot_options:
#     139         plot_options['auto_open'] = False
# --> 140     url = plot(figure_or_data, **plot_options)
#     141
#     142     if isinstance(figure_or_data, dict):
#
# /anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# /anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# /anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      23     except ValueError:
#      24         message = content if content else 'No Content'
# ---> 25         raise exceptions.PlotlyRequestError(message, status_code, content)
#      26
#      27     message = ''
#
# PlotlyRequestError:
# <html><head>
# <meta http-equiv="content-type" content="text/html;charset=utf-8">
# <title>502 Server Error</title>
# </head>
# <body text=#000000 bgcolor=#ffffff>
# <h1>Error: Server Error</h1>
# <h2>The server encountered a temporary error and could not complete your request.<p>Please try again in 30 seconds.</h2>
# <h2></h2>
# </body></html>
